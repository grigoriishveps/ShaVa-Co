# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Читаем. Смотрим

# %%
df = pd.read_csv("/content/drive/My Drive/Datasets_LCT/events.csv")

# %%
# data = pd.read_csv("/content/drive/My Drive/dataset/dirty/events.csv")

# %%
df.head()
# Out:
#      id  ...                                  Целевая аудитория
# 0     5  ...                                                NaN
# 1    12  ...          работающая молодежь, взрослые, пенсионеры
# 2  3179  ...  школьники, работающая молодежь, студенческая м...
# 3   486  ...               дети дошкольного возраста, школьники
# 4  2100  ...  дети дошкольного возраста, школьники, работающ...
#
# [5 rows x 25 columns]

# %% [markdown]
# # Дропаем ненужное

# %%
df = df.drop('Подразделение', 1)

# %%
df.head()
# Out:
#      id  ...                                  Целевая аудитория
# 0     5  ...                                                NaN
# 1    12  ...          работающая молодежь, взрослые, пенсионеры
# 2  3179  ...  школьники, работающая молодежь, студенческая м...
# 3   486  ...               дети дошкольного возраста, школьники
# 4  2100  ...  дети дошкольного возраста, школьники, работающ...
#
# [5 rows x 24 columns]

# %%
df = df.drop('Тип учреждения', 1)

# %%
df = df.drop('Мероприятие относится к ежегодным праздникам и общегородским мероприятиям', 1)

# %%
df = df.drop('Целевая аудитория', 1)

# %%
df.head()
# Out:
#      id  ... Возрастная категория
# 0     5  ...          от 20 до 40
# 1    12  ...          от 40 до 85
# 2  3179  ...         от 16 до 100
# 3   486  ...           от 5 до 14
# 4  2100  ...          от 15 до 80
#
# [5 rows x 21 columns]

# %% [markdown]
# # Стоимость полная
#
# Преобразуем в 3 столбца:
#
# 1) Стоимость:
#
#     0 - бесплатно
#     1 - платно
#
# 2) Стоимость ОТ
#
# 3) Стоимость ДО

# %%
df['Стоимость (полная)'].unique()
# Out:
# array(['бесплатное', 'платное (от 150 руб. до 150 руб.)', nan,
#        'платное (от 700 руб. до 3400 руб.)',
#        'платное (от 900 руб. до 1800 руб.)',
#        'платное (от 600 руб. до 1200 руб.)',
#        'платное (от 700 руб. до 1300 руб.)',
#        'платное (от 1000 руб. до 1000 руб.)',
#        'платное (от 500 руб. до 750 руб.)',
#        'платное (от 600 руб. до 2500 руб.)',
#        'платное (от 2950 руб. до 2950 руб.)',
#        'платное (от 700 руб. до 700 руб.)',
#        'платное (от 750 руб. до 4000 руб.)',
#        'платное (от 1200 руб. до 2500 руб.)',
#        'платное (от 750 руб. до 5000 руб.)',
#        'платное (от 1200 руб. до 3500 руб.)',
#        'платное (от 1000 руб. до 6000 руб.)',
#        'платное (от 70 руб. до 70 руб.)',
#        'платное (от 650 руб. до 800 руб.)',
#        'платное (от 5000 руб. до 5000 руб.)',
#        'платное (от 400 руб. до 600 руб.)',
#        'платное (от 600 руб. до 1600 руб.)',
#        'платное (от 500 руб. до 2000 руб.)',
#        'платное (от 300 руб. до 300 руб.)',
#        'платное (от 550 руб. до 750 руб.)',
#        'платное (от 1000 руб. до 3500 руб.)',
#        'платное (от 700 руб. до 2500 руб.)',
#        'платное (от 1000 руб. до 2800 руб.)',
#        'платное (от 500 руб. до 1000 руб.)',
#        'платное (от 25 руб. до 80 руб.)',
#        'платное,бесплатное (от 1000 руб. до 1000 руб.)',
#        'платное (от 1600 руб. до 1600 руб.)',
#        'платное,бесплатное (от 300 руб. до 700 руб.)',
#        'платное (от 200 руб. до 500 руб.)',
#        'платное,бесплатное (от 200 руб. до 500 руб.)',
#        'платное (от 300 руб. до 600 руб.)'], dtype=object)

# %%
df['Стоимость'] = '1'

# %%
df['Стоимость (полная)'].describe()
# Out:
# count          39606
# unique           219
# top       бесплатное
# freq           38084
# Name: Стоимость (полная), dtype: object

# %%
df.head()
# Out:
#      id  ... Стоимость
# 0     5  ...         1
# 1    12  ...         1
# 2  3179  ...         1
# 3   486  ...         1
# 4  2100  ...         1
#
# [5 rows x 22 columns]

# %%
df.loc[df['Стоимость (полная)'] == 'бесплатное', 'Стоимость'] = '0'

df.head()
# Out:
#      id  ... Стоимость
# 0     5  ...         0
# 1    12  ...         0
# 2  3179  ...         0
# 3   486  ...         0
# 4  2100  ...         0
#
# [5 rows x 22 columns]

# %%
df[df['Стоимость'] == '1'].count()
# Out:
# id                                        2990
# Название мероприятия                      2990
# Статус                                    2990
# Наименование учреждения                   2990
# Стоимость (полная)                        1522
# Тип мероприятия                           2989
# Направленность мероприятия                2921
# Наименование праздника или события         365
# Дата начала мероприятия                   2990
# Время начала мероприятия                  2402
# Дата окончания мероприятия                2990
# Время окончания мероприятия               2402
# Краткое описание                          2990
# Проводится онлайн                         2990
# Место проведения                          1968
# Округ                                     1881
# Район                                     1871
# Доступность мероприятия для лиц с ОВЗ     2008
# Тип ОВЗ                                    905
# Возрастной ценз участников мероприятия    2990
# Возрастная категория                      2990
# Стоимость                                 2990
# dtype: int64

# %%
def get_lists(x, d=0):
  if type(x) == list:
    if len(x) > 0:
      return x[d]
    else:
      return 0
  else:
    return 0

df_reg = df['Стоимость (полная)'].str.findall("\d+")
df['Стоимость от'] = df_reg.apply(get_lists,d=0)
df['Стоимость до'] = df_reg.apply(get_lists,d=1)

# %%
df.head()
# Out:
#      id  ... Стоимость до
# 0     5  ...            0
# 1    12  ...            0
# 2  3179  ...            0
# 3   486  ...            0
# 4  2100  ...            0
#
# [5 rows x 24 columns]

# %% [markdown]
# # Статус

# %%
df['Статус'].unique()
# Out:
# array(['Завершено', 'Утверждено', 'Запланировано', 'Отменено',
#        'Уточняется', 'Опубликовано'], dtype=object)

# %%
df[df['Статус'] == 'Уточняется'].count()
# Out:
# id                                        575
# Название мероприятия                      575
# Статус                                    575
# Наименование учреждения                   575
# Стоимость (полная)                        569
# Тип мероприятия                           575
# Направленность мероприятия                574
# Наименование праздника или события        163
# Дата начала мероприятия                   575
# Время начала мероприятия                  508
# Дата окончания мероприятия                575
# Время окончания мероприятия               508
# Краткое описание                          575
# Проводится онлайн                         575
# Место проведения                          538
# Округ                                     528
# Район                                     529
# Доступность мероприятия для лиц с ОВЗ     556
# Тип ОВЗ                                   159
# Возрастной ценз участников мероприятия    575
# Возрастная категория                      575
# Стоимость                                 575
# Стоимость от                              575
# Стоимость до                              575
# dtype: int64

# %%
df = df[(df['Статус'] != 'Завершено') & (df['Статус'] != 'Отменено')]

# %%
df.head()
# Out:
#       id                    Название мероприятия  ... Стоимость от Стоимость до
# 10  1273                     Вдохновение Ясенево  ...            0            0
# 11  1278                      Москва олимпийская  ...            0            0
# 12  1279                             Моё Ясенево  ...            0            0
# 13  1280  Завод, усадьба, ковш и подводная лодка  ...            0            0
# 14  1282              По следам старинных усадеб  ...            0            0
#
# [5 rows x 24 columns]

# %%
df.count()
# Out:
# id                                        5146
# Название мероприятия                      5146
# Статус                                    5146
# Наименование учреждения                   5146
# Стоимость (полная)                        4988
# Тип мероприятия                           5146
# Направленность мероприятия                5028
# Наименование праздника или события        1353
# Дата начала мероприятия                   5146
# Время начала мероприятия                  4433
# Дата окончания мероприятия                5146
# Время окончания мероприятия               4433
# Краткое описание                          5146
# Проводится онлайн                         5146
# Место проведения                          3702
# Округ                                     3580
# Район                                     3538
# Доступность мероприятия для лиц с ОВЗ     4613
# Тип ОВЗ                                   2450
# Возрастной ценз участников мероприятия    5146
# Возрастная категория                      5146
# Стоимость                                 5146
# Стоимость от                              5146
# Стоимость до                              5146
# dtype: int64

# %% [markdown]
# # Возрастной ценз

# %%
df['Возрастной ценз участников мероприятия'].describe()
# Out:
# count     5146
# unique       5
# top         6+
# freq      1755
# Name: Возрастной ценз участников мероприятия, dtype: object

# %%
df['Возрастной ценз участников мероприятия'].unique()
# Out:
# array(['0+', '6+', '12+', '18+', '16+'], dtype=object)

# %%
df['Возрастной ценз участников мероприятия'].count()
# Out:
# 5146

# %%
df.loc[df['Возрастной ценз участников мероприятия'] == '0+', 'Возрастной ценз'] = '0'
df.loc[df['Возрастной ценз участников мероприятия'] == '6+', 'Возрастной ценз'] = '6'
df.loc[df['Возрастной ценз участников мероприятия'] == '12+', 'Возрастной ценз'] = '12'
df.loc[df['Возрастной ценз участников мероприятия'] == '16+', 'Возрастной ценз'] = '16'
df.loc[df['Возрастной ценз участников мероприятия'] == '18+', 'Возрастной ценз'] = '18'

# %%
df = df.drop('Возрастной ценз участников мероприятия', 1)

# %%
df.head()
# Out:
#       id                    Название мероприятия  ... Стоимость до Возрастной ценз
# 10  1273                     Вдохновение Ясенево  ...            0               0
# 11  1278                      Москва олимпийская  ...            0               0
# 12  1279                             Моё Ясенево  ...            0               0
# 13  1280  Завод, усадьба, ковш и подводная лодка  ...            0               0
# 14  1282              По следам старинных усадеб  ...            0               0
#
# [5 rows x 24 columns]

# %% [markdown]
# # Проводится онлайн

# %%
df.loc[df['Проводится онлайн'] == 'Да', 'Онлайн'] = '1'
df.loc[df['Проводится онлайн'] == 'Нет', 'Онлайн'] = '0'
# df.count()

# %%
df['Проводится онлайн'].describe()
# Out:
# count     5146
# unique       2
# top        Нет
# freq      3704
# Name: Проводится онлайн, dtype: object

# %%
df['Проводится онлайн'].unique()
# Out:
# array(['Нет', 'Да'], dtype=object)

# %% [markdown]
# # ОВЗ

# %%
df.loc[df['Тип ОВЗ'] != 'NaN', 'ОВЗ'] = df['Тип ОВЗ']
df.loc[df['Доступность мероприятия для лиц с ОВЗ'] == 'недоступно', 'ОВЗ'] = 0
# df.loc[df['Тип ОВЗ'] != 'NaN', 'ОВЗ'] = df['Тип ОВЗ']
# df.count()

# %%
df.head()
# Out:
#       id                    Название мероприятия  ... Онлайн ОВЗ
# 10  1273                     Вдохновение Ясенево  ...      0   0
# 11  1278                      Москва олимпийская  ...      0   0
# 12  1279                             Моё Ясенево  ...      0   0
# 13  1280  Завод, усадьба, ковш и подводная лодка  ...      0   0
# 14  1282              По следам старинных усадеб  ...      0   0
#
# [5 rows x 26 columns]

# %%
df[df['ОВЗ'] == 0].count()
df['ОВЗ'].fillna(0) 
# df[df['ОВЗ'] == np.NaN].count()
# Out:
# 10                                                       0
# 11                                                       0
# 12                                                       0
# 13                                                       0
# 14                                                       0
#                                ...
# 41069    Опорно-двигательный аппарат, Слух, Инвалиды-ко...
# 41070                                                    0
# 41071                                                    0
# 41072    Опорно-двигательный аппарат, Инвалиды-колясочники
# 41073                                 Инвалиды-колясочники
# Name: ОВЗ, Length: 5146, dtype: object

# %%
df['ОВЗ'].unique()
# Out:
# array([0, 'Опорно-двигательный аппарат', 'Слух',
#        'Опорно-двигательный аппарат, Слух', nan,
#        'Опорно-двигательный аппарат, Инвалиды-колясочники', 'Зрение',
#        'Опорно-двигательный аппарат, Слух, Инвалиды-колясочники, Зрение',
#        'Опорно-двигательный аппарат, Зрение',
#        'Слух, Инвалиды-колясочники', 'Слух, Зрение',
#        'Опорно-двигательный аппарат, Слух, Инвалиды-колясочники',
#        'Опорно-двигательный аппарат, Слух, Зрение',
#        'Опорно-двигательный аппарат, Инвалиды-колясочники, Зрение',
#        'Инвалиды-колясочники', 'Слух, Инвалиды-колясочники, Зрение'],
#       dtype=object)

# %% [markdown]
# # Снова дропаем мусор

# %%
df.head()
# Out:
#       id                    Название мероприятия  ... Онлайн ОВЗ
# 10  1273                     Вдохновение Ясенево  ...      0   0
# 11  1278                      Москва олимпийская  ...      0   0
# 12  1279                             Моё Ясенево  ...      0   0
# 13  1280  Завод, усадьба, ковш и подводная лодка  ...      0   0
# 14  1282              По следам старинных усадеб  ...      0   0
#
# [5 rows x 26 columns]

# %%
df = df.drop('Стоимость (полная)', 1)
df = df.drop('Статус', 1)
df = df.drop('Доступность мероприятия для лиц с ОВЗ', 1)

# %% [markdown]
# # Возраст

# %%
df.head()
# Out:
#       id                    Название мероприятия  ... Онлайн ОВЗ
# 10  1273                     Вдохновение Ясенево  ...      0   0
# 11  1278                      Москва олимпийская  ...      0   0
# 12  1279                             Моё Ясенево  ...      0   0
# 13  1280  Завод, усадьба, ковш и подводная лодка  ...      0   0
# 14  1282              По следам старинных усадеб  ...      0   0
#
# [5 rows x 23 columns]

# %%
df['Возрастная категория'].describe()
# Out:
# count           5146
# unique           354
# top       от 6 до 99
# freq             226
# Name: Возрастная категория, dtype: object

# %%
df['Возрастная категория'].unique()
# Out:
# array(['от 0 до 90', 'от 6 до 14', 'от 12 до 99', 'от 35 до 85',
#        'от 18 до 35', 'от 18 до 80', 'от 6 до 12', 'от 6 до 90',
#        'от 12 до 90', 'от 18 до 45', 'от 35 до 80', 'от 16 до 99',
#        'от 0 до 99', 'от 9 до 13', 'от 9 до 14', 'от 12 до 70',
#        'от 12 до 16', 'от 16 до 80', 'от 50 до 90', 'от 50 до 95',
#        'от 30 до 70', 'от 20 до 70', 'от 30 до 60', 'от 18 до 60',
#        'от 6 до 35', 'от 18 до 98', 'от 6 до 70', 'от 18 до 85',
#        'от 6 до 80', 'от 18 до 99', 'от 55 до 99', 'от 4', 'от 6 до 16',
#        'от 6 до 55', 'от 12 до 30', 'от 8 до 12', 'от 12 до 18',
#        'от 4 до 70', 'от 8 до 10', 'от 18 до 75', 'от 4 до 12',
#        'от 16 до 70', 'от 16 до 55', 'от 6 до 10', 'от 6 до 99',
#        'от 6 до 45', 'от 4 до 10', 'от 16 до 90', 'от 2 до 99',
#        'от 6 до 100', 'от 3 до 12', 'от 16 до 60', 'от 12 до 60',
#        'от 14 до 80', 'от 14 до 99', 'от 55 до 85', 'от 7 до 14',
#        'от 55 до 90', 'от 16 до 25', 'от 16 до 24', 'от 10 до 16',
#        'от 12 до 85', 'от 7 до 10', 'от 12 до 14', 'от 8 до 14',
#        'от 3 до 6', 'от 6 до 8', 'от 12 до 15', 'от 31 до 90',
#        'от 16 до 85', 'от 10 до 11', 'от 7 до 100', 'от 16 до 50',
#        'от 12 до 80', 'от 4 до 45', 'от 4 до 50', 'от 6 до 7',
#        'от 4 до 14', 'от 6 до 50', 'от 0 до 12', 'от 4 до 6',
#        'от 3 до 90', 'от 7 до 75', 'от 3 до 99', 'от 10 до 14',
#        'от 0 до 80', 'от 0 до 17', 'от 14 до 16', 'от 3 до 7',
#        'от 12 до 25', 'от 55 до 80', 'от 25 до 40', 'от 20 до 55',
#        'от 45 до 99', 'от 25 до 80', 'от 6 до 15', 'от 8 до 9',
#        'от 10 до 15', 'от 25 до 99', 'от 12 до 35', 'от 9 до 10',
#        'от 0 до 6', 'от 7 до 12', 'от 3 до 14', 'от 9 до 12',
#        'от 12 до 17', 'от 8 до 99', 'от 6 до 9', 'от 35 до 55',
#        'от 25 до 50', 'от 14 до 35', 'от 30 до 99', 'от 6 до 18',
#        'от 12 до 100', 'от 8 до 13', 'от 15 до 30', 'от 0 до 100',
#        'от 18 до 90', 'от 7 до 8', 'от 3 до 10', 'от 18 до 70',
#        'от 16 до 35', 'от 6 до 24', 'от 18 до 65', 'от 5 до 45',
#        'от 1 до 3', 'от 0 до 70', 'от 5 до 40', 'от 16 до 100',
#        'от 10 до 99', 'от 2 до 3', 'от 3 до 4', 'от 6 до 17', 'от 12',
#        'от 6 до 75', 'от 5 до 14', 'от 5 до 10', 'от 10 до 20',
#        'от 6 до 30', 'от 12 до 50', 'от 6', 'от 4 до 80', 'от 16 до 45',
#        'от 2 до 10', 'от 5 до 7', 'от 18 до 88', 'от 1 до 5', 'от 5',
#        'от 4 до 100', 'от 2 до 6', 'от 12 до 75', 'от 5 до 60',
#        'от 4 до 25', 'от 6 до 25', 'от 9 до 18', 'от 35 до 70',
#        'от 10 до 30', 'от 5 до 6', 'от 7 до 15', 'от 12 до 55',
#        'от 5 до 99', 'от 15 до 99', 'от 18 до 95', 'от 8', 'от 0 до 50',
#        'от 6 до 56', 'от 12 до 65', 'от 2 до 5', 'от 6 до 6',
#        'от 35 до 60', 'от 0 до 14', 'от 4 до 15', 'от 0 до 56',
#        'от 12 до 56', 'от 0 до 75', 'от 0 до 7', 'от 3 до 85',
#        'от 10 до 70', 'от 16 до 96', 'от 5 до 65', 'от 7 до 99',
#        'от 15 до 80', 'от 5 до 95', 'от 11 до 12', 'от 9 до 11',
#        'от 6 до 65', 'от 10 до 12', 'от 3 до 100', 'от 50 до 99',
#        'от 6 до 85', 'от 8 до 80', 'от 18 до 64', 'от 3 до 8',
#        'от 8 до 18', 'от 35 до 99', 'от 10 до 80', 'от 11 до 14',
#        'от 10 до 18', 'от 2 до 11', 'от 10 до 80 до 14', 'от 0 до 18',
#        'от 4 до 8', 'от 16 до 64', 'от 3 до 45', 'от 50 до 80', 'от 35',
#        'от 5 до 13', 'от 6 до 11', 'от 4 до 99', 'от 6 до 60',
#        'от 31 до 50', 'от 5 до 8', 'от 1 до 80', 'от 14 до 60',
#        'от 4 до 11', 'от 5 до 12', 'от 3', 'от 4 до 7', 'от 60 до 99',
#        'от 6 до 92', 'от 5 до 90', 'от 10 до 90', 'от 8 до 55',
#        'от 14 до 40', 'от 7 до 9', 'от 12 до 45', 'от 14 до 75',
#        'от 4 до 16', 'от 14 до 90', 'от 6 до 95', 'от 18 до 55',
#        'от 3 до 80', 'от 40 до 85', 'от 5 до 85', 'от 16 до 30',
#        'от 16 до 40', 'от 0 до 85', 'от 16 до 65', 'от 40 до 80',
#        'от 12 до 64', 'от 18 до 100', 'от 8 до 98', 'от 4 до 75',
#        'от 12 до 92', 'от 14 до 65', 'от 16', 'от 10 до 17', 'от 14',
#        'от 5 до 17', 'от 0 до 45', 'от 0 до 8', 'от 50', 'от 16 до 110',
#        'от 7 до 80', 'от 14 до 22', 'от 7 до 13', 'от 30 до 80',
#        'от 35 до 90', 'от 18 до 30', 'от 5 до 80', 'от 30 до 75',
#        'от 8 до 75', 'от 2 до 40', 'от 6 до 96', 'от 18 до 56',
#        'от 0 до 0', 'от 15 до 75', 'от 5 до 9', 'от 12 до 20',
#        'от 30 до 55', 'от 35 до 56', 'от 12 до 19', 'от 50 до 85',
#        'от 12 до 88', 'от 4 до 5', 'от 6 до 21', 'от 16 до 18',
#        'от 30 до 90', 'от 4 до 90', 'от 8 до 50', 'от 5 до 15',
#        'от 7 до 25', 'от 8 до 15', 'от 4 до 9', 'от 11 до 15',
#        'от 14 до 70', 'от 45 до 90', 'от 18 до 25', 'от 7 до 56',
#        'от 5 до 55', 'от 16 до 56', 'от 12 до 12', 'от 1 до 90',
#        'от 4 до 85', 'от 10 до 56', 'от 2 до 90', 'от 7 до 11',
#        'от 14 до 56', 'от 20 до 90', 'от 3 до 70', 'от 4 до 60',
#        'от 2 до 50', 'от 8 до 70', 'от 3 до 15', 'от 15 до 85',
#        'от 6 до 20', 'от 8 до 20', 'от 25 до 56', 'от 55 до 75',
#        'от 7 до 95', 'от 5 до 50', 'от 3 до 50', 'от 14 до 30',
#        'от 16 до 75', 'от 3 до 16', 'от 45 до 80', 'от 2 до 4',
#        'от 3 до 5', 'от 30', 'от 35 до 95', 'от 20 до 99', 'от 8 до 11',
#        'от 14 до 18', 'от 17 до 90', 'от 30 до 85', 'от 8 до 16',
#        'от 2 до 18', 'от 14 до 17', 'от 15 до 24', 'от 50 до 100',
#        'от 16 до 95', 'от 31 до 99', 'от 10 до 50', 'от 45 до 70',
#        'от 8 до 60', 'от 18 до 22', 'от 10 до 100', 'от 16 до 88',
#        'от 35 до 75', 'от 3 до 60', 'от 3 до 18', 'от 25 до 70',
#        'от 5 до 64', 'от 4 до 18', 'от 0 до 55', 'от 5 до 5',
#        'от 3 до 25', 'от 55', 'от 1 до 60', 'от 0 до 9', 'от 0 до 65',
#        'от 2 до 14', 'от 1 до 14', 'от 20 до 60'], dtype=object)

# %%
df[df['Возрастная категория'] == 'от 4']
# Out:
#           id  ...                                                ОВЗ
# 15966    318  ...                                                  0
# 15968    320  ...                                                  0
# 15971    323  ...                                                  0
# 16357    709  ...                                                  0
# 16358    710  ...                                                  0
# 16359    711  ...                                                  0
# 16360    712  ...                                                  0
# 26105  10457  ...                                                  0
# 36760  10456  ...                Опорно-двигательный аппарат, Зрение
# 37198  10455  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 37750    314  ...                                                  0
# 37832    316  ...                                                  0
# 38258    315  ...                                                  0
# 38860    317  ...                                                  0
# 39151  10486  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 39414    319  ...                                                  0
# 40655    706  ...                                                  0
# 40773    324  ...                                                  0
# 40811    704  ...                                                  0
# 40812    715  ...                                                  0
# 40847    705  ...                                                  0
# 40848    740  ...                                                  0
# 40912    707  ...                                                  0
# 40934    708  ...                                                  0
# 40935    742  ...                                                  0
# 40992    325  ...                                                  0
#
# [26 rows x 23 columns]

# %%
df.loc[df['Возрастная категория'] == 'от 4', 'Возрастная категория'] = 'от 4 до 8'

# %%
df[df['Возрастная категория'] == 'от 12']
# Out:
#           id  ...                          ОВЗ
# 23510   7862  ...                          NaN
# 35635  10169  ...  Опорно-двигательный аппарат
# 35911  11068  ...                          NaN
# 36500  10171  ...                            0
# 38019   1218  ...                            0
#
# [5 rows x 23 columns]

# %%
df.loc[df['Возрастная категория'] == 'от 12', 'Возрастная категория'] = 'от 12 до 14'

# %%
df[df['Возрастная категория'] == 'от 6']
# Out:
#           id  ...                                                ОВЗ
# 24605   8957  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 25219   9571  ...  Опорно-двигательный аппарат, Слух, Инвалиды-ко...
# 25349   9701  ...                                                  0
# 26321  10673  ...                                                  0
# 27150  11502  ...                                                  0
# 34731   7869  ...                                                  0
# 35637   9221  ...                                                  0
# 35786  10179  ...                        Опорно-двигательный аппарат
# 35870   8958  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 36037   9510  ...                                                NaN
# 36125   9513  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 36297   9514  ...                                                  0
# 36350   9489  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 36496  10671  ...                                                  0
# 36775   9702  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 36850   9509  ...                                                NaN
# 36914   9515  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 37173  11483  ...                                                  0
# 37320   8973  ...                        Опорно-двигательный аппарат
# 37384   8999  ...                        Опорно-двигательный аппарат
# 37407   9512  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 37583  11665  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 37622   9498  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 38041  11494  ...                                                  0
# 38068  11469  ...                                                NaN
# 38085  11495  ...                                                  0
# 38172   8956  ...                                                  0
# 38261  11496  ...                                                  0
# 38588  11497  ...                                                  0
# 38605   9502  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 38761  11498  ...                                                  0
# 38824  10670  ...                                                  0
# 39209  10672  ...                                                  0
# 39399   1821  ...                                                  0
# 39700   1757  ...                                                NaN
# 39853   8955  ...                                                  0
# 40001   9508  ...                        Опорно-двигательный аппарат
# 40058   1811  ...                                                  0
# 40354   7868  ...                                                NaN
# 40358  10280  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 40461   1809  ...                                                  0
# 40578   1756  ...                                                  0
# 40618   1822  ...                                                NaN
# 40759   1758  ...                                                  0
# 40880   1873  ...                                                  0
#
# [45 rows x 23 columns]

# %%
df.loc[df['Возрастная категория'] == 'от 6', 'Возрастная категория'] = 'от 6 до 18'

# %%
df[df['Возрастная категория'] == 'от 5']
# Out:
#          id  ...                                                ОВЗ
# 25267  9619  ...                                                  0
# 25270  9622  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 35562  9625  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 35789  9621  ...                                                  0
# 36506  9624  ...                                                  0
# 37509  1650  ...                                                  0
# 37559  1668  ...                                                  0
# 38826  9615  ...                                                  0
# 40021  1672  ...                                                  0
# 40469  1649  ...                                                NaN
# 40519  1646  ...                                                  0
# 40520  1648  ...                                                  0
# 40673  1671  ...                                                  0
# 40693  1673  ...                                                  0
# 40822  1663  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 40856  1670  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 40884  1665  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 40885  1647  ...                                                NaN
# 40921  1666  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 40938  1667  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 40949  1669  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
#
# [21 rows x 23 columns]

# %%
df.loc[df['Возрастная категория'] == 'от 5', 'Возрастная категория'] = 'от 5 до 12'

# %%
df[df['Возрастная категория'] == 'от 8']
# Out:
#           id  ...                                                ОВЗ
# 26141  10493  ...                        Опорно-двигательный аппарат
# 35235  10492  ...                                                NaN
# 37377  11663  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 37884  11664  ...                                                NaN
# 38168   1024  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 38335   1060  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
#
# [6 rows x 23 columns]

# %%
df.loc[df['Возрастная категория'] == 'от 8', 'Возрастная категория'] = 'от 8 до 12'

# %%
df[df['Возрастная категория'] == 'от 35']
# Out:
#          id  ...                                                ОВЗ
# 35586  9598  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
#
# [1 rows x 23 columns]

# %%
df.loc[df['Возрастная категория'] == 'от 35', 'Возрастная категория'] = 'от 35 до 90'

# %%
df[df['Возрастная категория'] == 'от 3']
# Out:
#           id  ...                                                ОВЗ
# 35758  11596  ...                                                NaN
# 37389  11597  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 37637  11595  ...                                                NaN
# 38640  11449  ...  Опорно-двигательный аппарат, Слух, Инвалиды-ко...
# 39790    321  ...                                                  0
# 40119    322  ...                                                  0
#
# [6 rows x 23 columns]

# %%
df.loc[df['Возрастная категория'] == 'от 3', 'Возрастная категория'] = 'от 3 до 5'

# %%
df[df['Возрастная категория'] == 'от 16']
# Out:
#           id  ...                                                ОВЗ
# 36835   9573  ...                               Инвалиды-колясочники
# 37979  11454  ...                                                NaN
# 38219  11455  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
# 38567   9572  ...                        Опорно-двигательный аппарат
#
# [4 rows x 23 columns]

# %%
df.loc[df['Возрастная категория'] == 'от 16', 'Возрастная категория'] = 'от 12 до 16'

# %%
df[df['Возрастная категория'] == 'от 14']
# Out:
#          id  ...                                                ОВЗ
# 36876  8874  ...  Опорно-двигательный аппарат, Инвалиды-колясочники
#
# [1 rows x 23 columns]

# %%
df.loc[df['Возрастная категория'] == 'от 14', 'Возрастная категория'] = 'от 10 до 16'

# %%
df[df['Возрастная категория'] == 'от 50']
# Out:
#           id                               Название мероприятия  ... Онлайн  ОВЗ
# 37117  11731                                               Лира  ...      1    0
# 38364  11732                             Букет для любимой Мамы  ...      0  NaN
# 38920   9950                                      Осенний салат  ...      1    0
# 39037   9956  Мастер- класс по историко- бытовому и бальному...  ...      1    0
# 39217   9961                                        Осенний бал  ...      0    0
# 39712   5994            Спектакль современного танца Libertatem  ...      0    0
#
# [6 rows x 23 columns]

# %%
df.loc[df['Возрастная категория'] == 'от 50', 'Возрастная категория'] = 'от 50 до 90'

# %%
def get_lists(x, d=0):
  if type(x) == list:
    if len(x) > 0:
      # print(len(x), x)
      try:
        return x[d]
      except:
        return 90
    else:
      return 0
  else:
    return 0

df_reg = df['Возрастная категория'].str.findall("\d+")
df['Возраст от'] = df_reg.apply(get_lists,d=0)
df['Возраст до'] = df_reg.apply(get_lists,d=1)

# %%
df.head()
# Out:
#       id                    Название мероприятия  ... Возраст от Возраст до
# 10  1273                     Вдохновение Ясенево  ...          0         90
# 11  1278                      Москва олимпийская  ...          0         90
# 12  1279                             Моё Ясенево  ...          0         90
# 13  1280  Завод, усадьба, ковш и подводная лодка  ...          0         90
# 14  1282              По следам старинных усадеб  ...          0         90
#
# [5 rows x 25 columns]

# %%
df = df.drop('Стоимость', 1)
df = df.drop('Возрастная категория', 1)
# df = df.drop('Доступность мероприятия для лиц с ОВЗ', 1)

# %%
df.head()
# Out:
#       id                    Название мероприятия  ... Возраст от Возраст до
# 10  1273                     Вдохновение Ясенево  ...          0         90
# 11  1278                      Москва олимпийская  ...          0         90
# 12  1279                             Моё Ясенево  ...          0         90
# 13  1280  Завод, усадьба, ковш и подводная лодка  ...          0         90
# 14  1282              По следам старинных усадеб  ...          0         90
#
# [5 rows x 23 columns]

# %%
df.to_csv('/content/drive/My Drive/Datasets_LCT/new_events.csv')
